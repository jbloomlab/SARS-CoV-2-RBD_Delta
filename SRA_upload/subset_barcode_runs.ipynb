# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the main barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#            sample
# 0        267C_200
# 1        268C_500
# 2        273C_500
# 3        274C_500
# 4        276C_500
# 5        277C_500
# 6       278C_1250
# 7       279C_1250
# 8     Delta_1_500
# 9     Delta_3_350
# 10    Delta_4_350
# 11    Delta_6_500
# 12   Delta_7_1250
# 13    Delta_8_500
# 14  Delta_10_1250
# 15   Delta_11_500
# 16        P02_500
# 17       P03_1250
# 18       P04_1250
# 19        P05_500
# 20        P08_500
# 21        P09_200
# 22        P12_200
# 23       P14_1250

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#              name library  antibody  concentration    date  \
# 0        267C_200    lib1      267C            200  211119
# 1        267C_200    lib2      267C            200  211119
# 2        268C_500    lib1      268C            500  211112
# 3        268C_500    lib2      268C            500  211112
# 4        273C_500    lib1      273C            500  211119
# 5        273C_500    lib2      273C            500  211119
# 6        274C_500    lib1      274C            500  211119
# 7        274C_500    lib2      274C            500  211119
# 8        276C_500    lib1      276C            500  211119
# 9        276C_500    lib2      276C            500  211119
# 10       277C_500    lib1      277C            500  211119
# 11       277C_500    lib2      277C            500  211119
# 12      278C_1250    lib1      278C           1250  211119
# 13      278C_1250    lib2      278C           1250  211119
# 14      279C_1250    lib1      279C           1250  211112
# 15      279C_1250    lib2      279C           1250  211112
# 16    Delta_1_500    lib1   Delta_1            500  211122
# 17    Delta_1_500    lib2   Delta_1            500  211122
# 18  Delta_10_1250    lib1  Delta_10           1250  211122
# 19  Delta_10_1250    lib2  Delta_10           1250  211122
# 20   Delta_11_500    lib1  Delta_11            500  211122
# 21   Delta_11_500    lib2  Delta_11            500  211122
# 22    Delta_3_350    lib1   Delta_3            350  211122
# 23    Delta_3_350    lib2   Delta_3            350  211122
# 24    Delta_4_350    lib1   Delta_4            350  211122
# 25    Delta_4_350    lib2   Delta_4            350  211122
# 26    Delta_6_500    lib1   Delta_6            500  211122
# 27    Delta_6_500    lib2   Delta_6            500  211122
# 28   Delta_7_1250    lib1   Delta_7           1250  211122
# 29   Delta_7_1250    lib2   Delta_7           1250  211122
# 30    Delta_8_500    lib1   Delta_8            500  211122
# 31    Delta_8_500    lib2   Delta_8            500  211122
# 32        P02_500    lib1       P02            500  211124
# 33        P02_500    lib2       P02            500  211124
# 34       P03_1250    lib1       P03           1250  211112
# 35       P03_1250    lib2       P03           1250  211112
# 36       P04_1250    lib1       P04           1250  211124
# 37       P04_1250    lib2       P04           1250  211124
# 38        P05_500    lib1       P05            500  211124
# 39        P05_500    lib2       P05            500  211124
# 40        P08_500    lib1       P08            500  211112
# 41        P08_500    lib2       P08            500  211112
# 42        P09_200    lib1       P09            200  211124
# 43        P09_200    lib2       P09            200  211124
# 44        P12_200    lib1       P12            200  211124
# 45        P12_200    lib2       P12            200  211124
# 46       P14_1250    lib1       P14           1250  211124
# 47       P14_1250    lib2       P14           1250  211124
#
#                 pre_sample                   post_sample  frac_escape  \
# 0   delta_21-26-none-0-ref       delta_21-267C-200-abneg        0.112
# 1   delta_21-26-none-0-ref       delta_21-267C-200-abneg        0.094
# 2   delta_17-20-none-0-ref       delta_19-268C-500-abneg        0.107
# 3   delta_17-20-none-0-ref       delta_19-268C-500-abneg        0.119
# 4   delta_21-26-none-0-ref       delta_22-273C-500-abneg        0.126
# 5   delta_21-26-none-0-ref       delta_22-273C-500-abneg        0.125
# 6   delta_21-26-none-0-ref       delta_23-274C-500-abneg        0.122
# 7   delta_21-26-none-0-ref       delta_23-274C-500-abneg        0.108
# 8   delta_21-26-none-0-ref       delta_24-276C-500-abneg        0.126
# 9   delta_21-26-none-0-ref       delta_24-276C-500-abneg        0.108
# 10  delta_21-26-none-0-ref       delta_25-277C-500-abneg        0.112
# 11  delta_21-26-none-0-ref       delta_25-277C-500-abneg        0.108
# 12  delta_21-26-none-0-ref      delta_26-278C-1250-abneg        0.110
# 13  delta_21-26-none-0-ref      delta_26-278C-1250-abneg        0.106
# 14  delta_17-20-none-0-ref      delta_20-279C-1250-abneg        0.097
# 15  delta_17-20-none-0-ref      delta_20-279C-1250-abneg        0.097
# 16  delta_27-34-none-0-ref    delta_27-Delta_1-500-abneg        0.101
# 17  delta_27-34-none-0-ref    delta_27-Delta_1-500-abneg        0.094
# 18  delta_27-34-none-0-ref  delta_33-Delta_10-1250-abneg        0.084
# 19  delta_27-34-none-0-ref  delta_33-Delta_10-1250-abneg        0.073
# 20  delta_27-34-none-0-ref   delta_34-Delta_11-500-abneg        0.101
# 21  delta_27-34-none-0-ref   delta_34-Delta_11-500-abneg        0.084
# 22  delta_27-34-none-0-ref    delta_28-Delta_3-350-abneg        0.096
# 23  delta_27-34-none-0-ref    delta_28-Delta_3-350-abneg        0.098
# 24  delta_27-34-none-0-ref    delta_29-Delta_4-350-abneg        0.069
# 25  delta_27-34-none-0-ref    delta_29-Delta_4-350-abneg        0.068
# 26  delta_27-34-none-0-ref    delta_30-Delta_6-500-abneg        0.108
# 27  delta_27-34-none-0-ref    delta_30-Delta_6-500-abneg        0.109
# 28  delta_27-34-none-0-ref   delta_31-Delta_7-1250-abneg        0.099
# 29  delta_27-34-none-0-ref   delta_31-Delta_7-1250-abneg        0.091
# 30  delta_27-34-none-0-ref    delta_32-Delta_8-500-abneg        0.102
# 31  delta_27-34-none-0-ref    delta_32-Delta_8-500-abneg        0.095
# 32  delta_35-40-none-0-ref        delta_35-P02-500-abneg        0.088
# 33  delta_35-40-none-0-ref        delta_35-P02-500-abneg        0.079
# 34  delta_17-20-none-0-ref       delta_17-P03-1250-abneg        0.094
# 35  delta_17-20-none-0-ref       delta_17-P03-1250-abneg        0.087
# 36  delta_35-40-none-0-ref       delta_36-P04-1250-abneg        0.107
# 37  delta_35-40-none-0-ref       delta_36-P04-1250-abneg        0.087
# 38  delta_35-40-none-0-ref        delta_37-P05-500-abneg        0.085
# 39  delta_35-40-none-0-ref        delta_37-P05-500-abneg        0.086
# 40  delta_17-20-none-0-ref        delta_18-P08-500-abneg        0.112
# 41  delta_17-20-none-0-ref        delta_18-P08-500-abneg        0.121
# 42  delta_35-40-none-0-ref        delta_38-P09-200-abneg        0.096
# 43  delta_35-40-none-0-ref        delta_38-P09-200-abneg        0.089
# 44  delta_35-40-none-0-ref        delta_39-P12-200-abneg        0.101
# 45  delta_35-40-none-0-ref        delta_39-P12-200-abneg        0.096
# 46  delta_35-40-none-0-ref       delta_40-P14-1250-abneg        0.094
# 47  delta_35-40-none-0-ref       delta_40-P14-1250-abneg        0.087
#
#     pre_cells_sorted  post_cells_sorted
# 0          1206433.0                NaN
# 1          1078707.0                NaN
# 2          1012056.0                NaN
# 3          1023050.0                NaN
# 4          1269137.0                NaN
# 5          1249629.0                NaN
# 6          1233005.0                NaN
# 7          1094894.0                NaN
# 8          1263014.0                NaN
# 9          1091168.0                NaN
# 10         1137613.0                NaN
# 11         1135069.0                NaN
# 12         1106454.0                NaN
# 13         1106060.0                NaN
# 14         1026589.0                NaN
# 15         1077475.0                NaN
# 16         1061841.0                NaN
# 17         1044979.0                NaN
# 18          846975.0                NaN
# 19          749075.0                NaN
# 20         1017425.0                NaN
# 21          847856.0                NaN
# 22         1031277.0                NaN
# 23         1180295.0                NaN
# 24          701150.0                NaN
# 25          693528.0                NaN
# 26         1093297.0                NaN
# 27         1091332.0                NaN
# 28         1231047.0                NaN
# 29          926411.0                NaN
# 30         1024951.0                NaN
# 31          967074.0                NaN
# 32          927272.0                NaN
# 33          808248.0                NaN
# 34         1022039.0                NaN
# 35         1012373.0                NaN
# 36         1079672.0                NaN
# 37          875369.0                NaN
# 38          909556.0                NaN
# 39          892227.0                NaN
# 40         1015086.0                NaN
# 41         1045993.0                NaN
# 42          964559.0                NaN
# 43          904976.0                NaN
# 44         1017353.0                NaN
# 45          964926.0                NaN
# 46          953329.0                NaN
# 47          872522.0                NaN

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#    library                        sample    date   experiment  antibody  \
# 0     lib1        delta_21-26-none-0-ref  211119  delta_21-26      none
# 1     lib2        delta_21-26-none-0-ref  211119  delta_21-26      none
# 2     lib1        delta_17-20-none-0-ref  211112  delta_17-20      none
# 3     lib2        delta_17-20-none-0-ref  211112  delta_17-20      none
# 4     lib1        delta_27-34-none-0-ref  211122  delta_27-34      none
# 5     lib2        delta_27-34-none-0-ref  211122  delta_27-34      none
# 6     lib1        delta_35-40-none-0-ref  211124  delta_35-40      none
# 7     lib2        delta_35-40-none-0-ref  211124  delta_35-40      none
# 8     lib1       delta_21-267C-200-abneg  211119     delta_21      267C
# 9     lib2       delta_21-267C-200-abneg  211119     delta_21      267C
# 10    lib1       delta_19-268C-500-abneg  211112     delta_19      268C
# 11    lib2       delta_19-268C-500-abneg  211112     delta_19      268C
# 12    lib1       delta_22-273C-500-abneg  211119     delta_22      273C
# 13    lib2       delta_22-273C-500-abneg  211119     delta_22      273C
# 14    lib1       delta_23-274C-500-abneg  211119     delta_23      274C
# 15    lib2       delta_23-274C-500-abneg  211119     delta_23      274C
# 16    lib1       delta_24-276C-500-abneg  211119     delta_24      276C
# 17    lib2       delta_24-276C-500-abneg  211119     delta_24      276C
# 18    lib1       delta_25-277C-500-abneg  211119     delta_25      277C
# 19    lib2       delta_25-277C-500-abneg  211119     delta_25      277C
# 20    lib1      delta_26-278C-1250-abneg  211119     delta_26      278C
# 21    lib2      delta_26-278C-1250-abneg  211119     delta_26      278C
# 22    lib1      delta_20-279C-1250-abneg  211112     delta_20      279C
# 23    lib2      delta_20-279C-1250-abneg  211112     delta_20      279C
# 24    lib1    delta_27-Delta_1-500-abneg  211122     delta_27   Delta_1
# 25    lib2    delta_27-Delta_1-500-abneg  211122     delta_27   Delta_1
# 26    lib1  delta_33-Delta_10-1250-abneg  211122     delta_33  Delta_10
# 27    lib2  delta_33-Delta_10-1250-abneg  211122     delta_33  Delta_10
# 28    lib1   delta_34-Delta_11-500-abneg  211122     delta_34  Delta_11
# 29    lib2   delta_34-Delta_11-500-abneg  211122     delta_34  Delta_11
# 30    lib1    delta_28-Delta_3-350-abneg  211122     delta_28   Delta_3
# 31    lib2    delta_28-Delta_3-350-abneg  211122     delta_28   Delta_3
# 32    lib1    delta_29-Delta_4-350-abneg  211122     delta_29   Delta_4
# 33    lib2    delta_29-Delta_4-350-abneg  211122     delta_29   Delta_4
# 34    lib1    delta_30-Delta_6-500-abneg  211122     delta_30   Delta_6
# 35    lib2    delta_30-Delta_6-500-abneg  211122     delta_30   Delta_6
# 36    lib1   delta_31-Delta_7-1250-abneg  211122     delta_31   Delta_7
# 37    lib2   delta_31-Delta_7-1250-abneg  211122     delta_31   Delta_7
# 38    lib1    delta_32-Delta_8-500-abneg  211122     delta_32   Delta_8
# 39    lib2    delta_32-Delta_8-500-abneg  211122     delta_32   Delta_8
# 40    lib1        delta_35-P02-500-abneg  211124     delta_35       P02
# 41    lib2        delta_35-P02-500-abneg  211124     delta_35       P02
# 42    lib1       delta_17-P03-1250-abneg  211112     delta_17       P03
# 43    lib2       delta_17-P03-1250-abneg  211112     delta_17       P03
# 44    lib1       delta_36-P04-1250-abneg  211124     delta_36       P04
# 45    lib2       delta_36-P04-1250-abneg  211124     delta_36       P04
# 46    lib1        delta_37-P05-500-abneg  211124     delta_37       P05
# 47    lib2        delta_37-P05-500-abneg  211124     delta_37       P05
# 48    lib1        delta_18-P08-500-abneg  211112     delta_18       P08
# 49    lib2        delta_18-P08-500-abneg  211112     delta_18       P08
# 50    lib1        delta_38-P09-200-abneg  211124     delta_38       P09
# 51    lib2        delta_38-P09-200-abneg  211124     delta_38       P09
# 52    lib1        delta_39-P12-200-abneg  211124     delta_39       P12
# 53    lib2        delta_39-P12-200-abneg  211124     delta_39       P12
# 54    lib1       delta_40-P14-1250-abneg  211124     delta_40       P14
# 55    lib2       delta_40-P14-1250-abneg  211124     delta_40       P14
#
#     concentration sort_bin             HutchBase experiment_type  \
# 0             0.0      ref  delta_21-26_lib1_ref    ab_selection
# 1             0.0      ref  delta_21-26_lib2_ref    ab_selection
# 2             0.0      ref  delta_17-20_lib1_ref    ab_selection
# 3             0.0      ref  delta_17-20_lib2_ref    ab_selection
# 4             0.0      ref  delta_27-34_lib1_ref    ab_selection
# 5             0.0      ref  delta_27-34_lib2_ref    ab_selection
# 6             0.0      ref  delta_35-40_lib1_ref    ab_selection
# 7             0.0      ref  delta_35-40_lib2_ref    ab_selection
# 8           200.0    abneg   delta_21_lib1_abneg    ab_selection
# 9           200.0    abneg   delta_21_lib2_abneg    ab_selection
# 10          500.0    abneg   delta_19_lib1_abneg    ab_selection
# 11          500.0    abneg   delta_19_lib2_abneg    ab_selection
# 12          500.0    abneg   delta_22_lib1_abneg    ab_selection
# 13          500.0    abneg   delta_22_lib2_abneg    ab_selection
# 14          500.0    abneg   delta_23_lib1_abneg    ab_selection
# 15          500.0    abneg   delta_23_lib2_abneg    ab_selection
# 16          500.0    abneg   delta_24_lib1_abneg    ab_selection
# 17          500.0    abneg   delta_24_lib2_abneg    ab_selection
# 18          500.0    abneg   delta_25_lib1_abneg    ab_selection
# 19          500.0    abneg   delta_25_lib2_abneg    ab_selection
# 20         1250.0    abneg   delta_26_lib1_abneg    ab_selection
# 21         1250.0    abneg   delta_26_lib2_abneg    ab_selection
# 22         1250.0    abneg   delta_20_lib1_abneg    ab_selection
# 23         1250.0    abneg   delta_20_lib2_abneg    ab_selection
# 24          500.0    abneg   delta_27_lib1_abneg    ab_selection
# 25          500.0    abneg   delta_27_lib2_abneg    ab_selection
# 26         1250.0    abneg   delta_33_lib1_abneg    ab_selection
# 27         1250.0    abneg   delta_33_lib2_abneg    ab_selection
# 28          500.0    abneg   delta_34_lib1_abneg    ab_selection
# 29          500.0    abneg   delta_34_lib2_abneg    ab_selection
# 30          350.0    abneg   delta_28_lib1_abneg    ab_selection
# 31          350.0    abneg   delta_28_lib2_abneg    ab_selection
# 32          350.0    abneg   delta_29_lib1_abneg    ab_selection
# 33          350.0    abneg   delta_29_lib2_abneg    ab_selection
# 34          500.0    abneg   delta_30_lib1_abneg    ab_selection
# 35          500.0    abneg   delta_30_lib2_abneg    ab_selection
# 36         1250.0    abneg   delta_31_lib1_abneg    ab_selection
# 37         1250.0    abneg   delta_31_lib2_abneg    ab_selection
# 38          500.0    abneg   delta_32_lib1_abneg    ab_selection
# 39          500.0    abneg   delta_32_lib2_abneg    ab_selection
# 40          500.0    abneg   delta_35_lib1_abneg    ab_selection
# 41          500.0    abneg   delta_35_lib2_abneg    ab_selection
# 42         1250.0    abneg   delta_17_lib1_abneg    ab_selection
# 43         1250.0    abneg   delta_17_lib2_abneg    ab_selection
# 44         1250.0    abneg   delta_36_lib1_abneg    ab_selection
# 45         1250.0    abneg   delta_36_lib2_abneg    ab_selection
# 46          500.0    abneg   delta_37_lib1_abneg    ab_selection
# 47          500.0    abneg   delta_37_lib2_abneg    ab_selection
# 48          500.0    abneg   delta_18_lib1_abneg    ab_selection
# 49          500.0    abneg   delta_18_lib2_abneg    ab_selection
# 50          200.0    abneg   delta_38_lib1_abneg    ab_selection
# 51          200.0    abneg   delta_38_lib2_abneg    ab_selection
# 52          200.0    abneg   delta_39_lib1_abneg    ab_selection
# 53          200.0    abneg   delta_39_lib2_abneg    ab_selection
# 54         1250.0    abneg   delta_40_lib1_abneg    ab_selection
# 55         1250.0    abneg   delta_40_lib2_abneg    ab_selection
#
#     number_cells  frac_escape  \
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# 5            NaN          NaN
# 6            NaN          NaN
# 7            NaN          NaN
# 8      1206433.0        0.112
# 9      1078707.0        0.094
# 10     1012056.0        0.107
# 11     1023050.0        0.119
# 12     1269137.0        0.126
# 13     1249629.0        0.125
# 14     1233005.0        0.122
# 15     1094894.0        0.108
# 16     1263014.0        0.126
# 17     1091168.0        0.108
# 18     1137613.0        0.112
# 19     1135069.0        0.108
# 20     1106454.0        0.110
# 21     1106060.0        0.106
# 22     1026589.0        0.097
# 23     1077475.0        0.097
# 24     1061841.0        0.101
# 25     1044979.0        0.094
# 26      846975.0        0.084
# 27      749075.0        0.073
# 28     1017425.0        0.101
# 29      847856.0        0.084
# 30     1031277.0        0.096
# 31     1180295.0        0.098
# 32      701150.0        0.069
# 33      693528.0        0.068
# 34     1093297.0        0.108
# 35     1091332.0        0.109
# 36     1231047.0        0.099
# 37      926411.0        0.091
# 38     1024951.0        0.102
# 39      967074.0        0.095
# 40      927272.0        0.088
# 41      808248.0        0.079
# 42     1022039.0        0.094
# 43     1012373.0        0.087
# 44     1079672.0        0.107
# 45      875369.0        0.087
# 46      909556.0        0.085
# 47      892227.0        0.086
# 48     1015086.0        0.112
# 49     1045993.0        0.121
# 50      964559.0        0.096
# 51      904976.0        0.089
# 52     1017353.0        0.101
# 53      964926.0        0.096
# 54      953329.0        0.094
# 55      872522.0        0.087
#
#                                                    R1
# 0   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 1   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 2   /shared/ngs/illumina/agreaney/211117_D00300_13...
# 3   /shared/ngs/illumina/agreaney/211117_D00300_13...
# 4   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 5   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 6   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 7   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 8   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 9   /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 10  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 11  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 12  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 13  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 14  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 15  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 16  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 17  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 18  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 19  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 20  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 21  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 22  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 23  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 24  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 25  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 26  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 27  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 28  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 29  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 30  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 31  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 32  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 33  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 34  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 35  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 36  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 37  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 38  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 39  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 40  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 41  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 42  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 43  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 44  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 45  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 46  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 47  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 48  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 49  /shared/ngs/illumina/agreaney/211117_D00300_13...
# 50  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 51  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 52  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 53  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 54  /shared/ngs/illumina/agreaney/211130_VH00699_2...
# 55  /shared/ngs/illumina/agreaney/211130_VH00699_2...
